# %%
import pandas as pd
import numpy as np
import mlxtend
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from mlxtend.frequent_patterns import association_rules 
df = pd.read_csv("C:/Users/DELL/Downloads/Market_Basket_Optimisation.csv",header=None)
display(df)
df_= df.to_numpy().tolist()
df_2 = []
for i in df_:
    c = []
    m = [str(x) for x in i]
    c = [j for j in m if j != 'nan']
    df_2.append(c)
print(df_2)
# Out:
#                  0                  1            2                 3   \
# 0            shrimp            almonds      avocado    vegetables mix
# 1           burgers          meatballs         eggs               NaN
# 2           chutney                NaN          NaN               NaN
# 3            turkey            avocado          NaN               NaN
# 4     mineral water               milk   energy bar  whole wheat rice
# ...             ...                ...          ...               ...
# 7496         butter         light mayo  fresh bread               NaN
# 7497        burgers  frozen vegetables         eggs      french fries
# 7498        chicken                NaN          NaN               NaN
# 7499       escalope          green tea          NaN               NaN
# 7500           eggs    frozen smoothie  yogurt cake    low fat yogurt
#
#                 4                 5     6               7             8   \
# ...

# %%
te=TransactionEncoder()
te_ary=te.fit(df_2).transform(df_2)
df_3=pd.DataFrame(te_ary, columns=te.columns_)
display(df_3)
frequent_itemsets=apriori(df_3, min_support=0.05, use_colnames=True)
display(frequent_itemsets)
display(association_rules(frequent_itemsets,metric="confidence",min_threshold=0.2))
display(association_rules(frequent_itemsets,metric="lift",min_threshold=1.25))
# Out:
#        asparagus  almonds  antioxydant juice  asparagus  avocado  babies food  \
# 0          False     True               True      False     True        False
# 1          False    False              False      False    False        False
# 2          False    False              False      False    False        False
# 3          False    False              False      False     True        False
# 4          False    False              False      False    False        False
# ...          ...      ...                ...        ...      ...          ...
# 7496       False    False              False      False    False        False
# 7497       False    False              False      False    False        False
# 7498       False    False              False      False    False        False
# 7499       False    False              False      False    False        False
# 7500       False    False              False      False    False        False
#
# ...

# %%
import matplotlib.pyplot as plt
l = {}
for col in df_3.columns:
    a = len(df_3.loc[df_3[col] == True])
    l[col]=a
del l[' asparagus']
v = list(l.keys())
p = list(l.values())
print(len(p))
plt.subplots_adjust(left=0.01,bottom=0.2,right=3,top=11,hspace=0.7)
plt.subplot(6,1,1)
plt.bar(v[0:20],p[0:20], width = 0.2)
plt.xticks(rotation=-60,fontsize=20)
plt.yticks(fontsize=20)

plt.subplot(6,1,2)
plt.bar(v[20:40],p[20:40], width = 0.2,color='red')
plt.xticks(rotation=-60,fontsize=20)
plt.yticks(fontsize=20)

plt.subplot(6,1,3)
plt.bar(v[40:60],p[40:60], width = 0.2,color='green')
plt.xticks(rotation=-60,fontsize=20)
plt.yticks(fontsize=20)

plt.subplot(6,1,4)
plt.bar(v[60:80],p[60:80], width = 0.2,color='orange')
plt.xticks(rotation=-60,fontsize=20)
plt.yticks(fontsize=20)

plt.subplot(6,1,5)
plt.bar(v[80:100],p[80:100], width = 0.2,color='yellow')
plt.xticks(rotation=-60,fontsize=20)
plt.yticks(fontsize=20)

plt.subplot(6,1,6)
plt.bar(v[100:118],p[100:118], width = 0.2,color='pink')
plt.xticks(rotation=-60,fontsize=20)
plt.yticks(fontsize=20)
plt.show()
# Out:
# 119

# %% [markdown]
# as we can see it is likely that the one who is gonna buy a spaghetti is gonna also buy a mineral water , also mineral water and chocolate

# %%
dataset = [['Skirt', 'Sneakers', 'Scarf', 'Pants', 'Hat'],

    ['Sunglasses', 'Skirt', 'Sneakers', 'Pants', 'Hat'],

    ['Dress', 'Sandals', 'Scarf', 'Pants', 'Heels'],

    ['Dress', 'Necklace', 'Earrings', 'Scarf', 'Hat', 'Heels', 'Hat'],

   ['Earrings', 'Skirt', 'Skirt', 'Scarf', 'Shirt', 'Pants']]

# %%
t=TransactionEncoder()
t_ary=t.fit(dataset).transform(dataset)
df4=pd.DataFrame(t_ary, columns=t.columns_)
display(df4)
frequent_itemset=apriori(df4, min_support=0.4, use_colnames=True)
display(frequent_itemset)
display(association_rules(frequent_itemset,metric="confidence",min_threshold=0.7))
display(association_rules(frequent_itemset,metric="lift",min_threshold=1.25))
# Out:
#    Dress  Earrings    Hat  Heels  Necklace  Pants  Sandals  Scarf  Shirt  \
# 0  False     False   True  False     False   True    False   True  False
# 1  False     False   True  False     False   True    False  False  False
# 2   True     False  False   True     False   True     True   True  False
# 3   True      True   True   True      True  False    False   True  False
# 4  False      True  False  False     False   True    False   True   True
#
#    Skirt  Sneakers  Sunglasses
# 0   True      True       False
# 1   True      True        True
# 2  False     False       False
# 3  False     False       False
# 4   True     False       False
#     support                       itemsets
# 0       0.4                        (Dress)
# 1       0.4                     (Earrings)
# 2       0.6                          (Hat)
# 3       0.4                        (Heels)
# 4       0.8                        (Pants)
# 5       0.8                        (Scarf)
# ...

# %% [markdown]
# it is likely as well that the woman who's gonna buy a dress will buy a heel but if a customer bought a pants he probably wouldn't buy a hat and a sneaker and a skirt
